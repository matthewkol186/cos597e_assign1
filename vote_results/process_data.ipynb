# %% [markdown]
# # Processing NYT Election data
#
# The goal of this notebook is to process the JSONs received from the NYT APIs into CSVs that will be easier to work with.

# %%
import pandas as pd
import json
from collections import defaultdict
import pprint

# %% [markdown]
# ## House data

# %%
with open('house_11-23.json') as f:
  house_json = json.load(f)

# %%
# for one house race, tally vote results
random_race = house_json['data']['races'][0]
race_results = {'democrat': 0, 'republican': 0}
opposite_party = {'democrat': 'republican', 'republican': 'democrat'}
for c in random_race['counties']:
    votes = c['results'].values()
    if(len(votes) > 2):
        print("Warning...something spooky...")
        print(c)
        print("")
    max_votes = max(votes)
    min_votes = min(votes)
    race_results[c['leader_party_id']] += max_votes
    race_results[opposite_party[c['leader_party_id']]] += min_votes
    
print(race_results)
print(random_race['leader_margin_votes'])
print(race_results[random_race['leader_party_id']] - race_results[opposite_party[random_race['leader_party_id']]])
print(random_race.keys())
print(random_race['state_id'])
print(random_race['seat'])
pprint.pprint(random_race['candidates'])
# Out:
# {'democrat': 159765, 'republican': 191568}
# 31803
# 31803
# dict_keys(['race_id', 'race_slug', 'url', 'state_page_url', 'ap_polls_page', 'race_type', 'election_type', 'election_date', 'runoff', 'race_name', 'office', 'officeid', 'nyt_race_description', 'race_rating', 'nyt_key_race', 'seat', 'seat_name', 'state_id', 'state_slug', 'state_name', 'state_nyt_abbrev', 'state_shape', 'state_aspect_ratio', 'party_id', 'uncontested', 'report', 'result', 'result_source', 'gain', 'lost_seat', 'votes', 'absentee_votes', 'absentee_counties', 'absentee_count_progress', 'absentee_outstanding', 'absentee_max_ballots', 'provisional_outstanding', 'provisional_count_progress', 'poll_display', 'poll_countdown_display', 'poll_waiting_display', 'poll_time', 'poll_time_short', 'precincts_reporting', 'precincts_total', 'reporting_display', 'reporting_value', 'eevp', 'tot_exp_vote', 'eevp_source', 'eevp_value', 'eevp_display', 'county_data_source', 'incumbent_party', 'no_forecast', 'last_updated', 'candidates', 'has_incumbent', 'leader_margin_value', 'leader_margin_votes', 'leader_margin_display', 'leader_margin_name_display', 'leader_party_id', 'counties', 'expectations_text', 'expectations_text_short', 'absentee_ballot_deadline', 'absentee_postmark_deadline', 'update_sentences', 'race_diff', 'winnerCalledTimestamp', 'timeseries'])
# AK
# 1
# [{'absentee_percent': 43.6,
#   'absentee_votes': 75308,
#   'candidate_id': 'young-513-2-h',
#   'candidate_key': 'youngd',
#   'electoral_votes': 0,
#   'first_name': 'Don',
#   'has_image': False,
#   'img_url': 'https://static01.nyt.com/elections-assets/2020/assets/images/candidates/young-513-2-h.png',
#   'incumbent': True,
#   'last_name': 'Young',
#   'link': '',
#   'name_display': 'Don Young',
#   'order': 2,
#   'party_id': 'republican',
#   'percent': 54.5,
#   'percent_display': '54.5',
#   'runoff': False,
#   'votes': 191568,
#   'winner': True},
#  {'absentee_percent': 56.4,
#   'absentee_votes': 97424,
#   'candidate_id': 'galvin-20160-2-h',
#   'candidate_key': 'galvina',
#   'electoral_votes': 0,
#   'first_name': 'Alyse',
#   'has_image': False,
#   'img_url': 'https://static01.nyt.com/elections-assets/2020/assets/images/candidates/galvin-20160-2-h.png',
#   'incumbent': False,
#   'last_name': 'Galvin',
#   'link': '',
#   'name_display': 'Alyse Galvin',
#   'order': 1,
#   'party_id': 'democrat',
#   'percent': 45.5,
#   'percent_display': '45.5',
#   'runoff': False,
#   'votes': 159765,
#   'winner': False}]

# %%
party_ids = set()
for r in house_json['data']['races']:
    for c in r['candidates']:
        party_ids.add(c['party_id'])
            
print(party_ids)
# Out:
# {'Alo', 'unity', 'Tax', 'Uu', 'constitution', 'Pop', 'Wfl', 'Apv', 'working-class', 'Grp', 'Ecl', 'Com', 'write-ins', 'no-party-affiliation', 'serve-america-movement', 'conservative', 'democrat', 'green', 'libertarian', 'independent-american', 'independent', 'pacific-green', 'Npt', 'republican'}

# %%
results = defaultdict(list)
# keys: state_id, seat, d_votes, r_votes, other_votes, d_vote_share, r_vote_share, d_winner, r_winner, STATEFP, CD114FP

state_codes = {
    'WA': '53', 'DE': '10', 'DC': '11', 'WI': '55', 'WV': '54', 'HI': '15',
    'FL': '12', 'WY': '56', 'PR': '72', 'NJ': '34', 'NM': '35', 'TX': '48',
    'LA': '22', 'NC': '37', 'ND': '38', 'NE': '31', 'TN': '47', 'NY': '36',
    'PA': '42', 'AK': '02', 'NV': '32', 'NH': '33', 'VA': '51', 'CO': '08',
    'CA': '06', 'AL': '01', 'AR': '05', 'VT': '50', 'IL': '17', 'GA': '13',
    'IN': '18', 'IA': '19', 'MA': '25', 'AZ': '04', 'ID': '16', 'CT': '09',
    'ME': '23', 'MD': '24', 'OK': '40', 'OH': '39', 'UT': '49', 'MO': '29',
    'MN': '27', 'MI': '26', 'RI': '44', 'KS': '20', 'MT': '30', 'MS': '28',
    'SC': '45', 'KY': '21', 'OR': '41', 'SD': '46'
}

for r in house_json['data']['races']:
    if r['leader_margin_votes'] is None or len(r['leader_party_id']) == 0:
        # skip if the data is insufficient
        continue
    race_results = {'democrat': 0, 'republican': 0, 'other': 0}
    winning_party = {'d_won': 0, 'r_won': 0, 'other_won': 0}
    for c in r['candidates']:
        if c['party_id'] not in ['democrat', 'republican']:
            c['party_id'] = 'other'
        race_results[c['party_id']] += c['votes']
        if c['winner']:
            if c['party_id'] == 'democrat':
                winning_party['d_won'] = 1
            elif c['party_id'] == 'republican':
                winning_party['r_won'] = 1
            else:
                winning_party['other_won'] = 1
                
    results['state_id'].append(r['state_id'])
    results['STATEFP'].append(state_codes[r['state_id']])
    results['seat_id'].append(r['seat'])
    # copied from seat_id
    results['CD114FP'].append(r['seat'])
    
    # vote counts
    results['d_votes'].append(race_results['democrat'])
    results['r_votes'].append(race_results['republican'])
    results['other_votes'].append(race_results['other'])
    # vote shares
    total_votes = sum(race_results.values())
    results['d_vote_share'].append(race_results['democrat'] / total_votes)
    results['r_vote_share'].append(race_results['republican'] / total_votes)
    results['other_vote_share'].append(race_results['other'] / total_votes)
    
    for k in winning_party.keys():
        results[k].append(winning_party[k])

# %%
house_df = pd.DataFrame.from_dict(results)
house_df.head()
# Out:
#   state_id STATEFP  seat_id  CD114FP  d_votes  r_votes  other_votes  \
# 0       AK      02        1        1   159765   191568            0
# 1       AL      01        1        1   116949   211825            0
# 2       AL      01        2        2   105286   197996          287
# 3       AL      01        3        3   104595   217384            0
# 4       AL      01        4        4    56237   261553            0
#
#    d_vote_share  r_vote_share  other_vote_share  d_won  r_won  other_won
# 0      0.454740      0.545260          0.000000      0      1          0
# 1      0.355712      0.644288          0.000000      0      1          0
# 2      0.346827      0.652227          0.000945      0      1          0
# 3      0.324850      0.675150          0.000000      0      1          0
# 4      0.176963      0.823037          0.000000      0      1          0

# %%
house_df.shape
# Out:
# (428, 13)

# %%
# some sanity checks
print(house_df['d_won'].sum())
print(house_df['r_won'].sum())
print(house_df['other_won'].sum())
# Out:
# 219
# 200
# 0

# %%
house_called_df = house_df[(house_df['d_won'] == 1) | (house_df['r_won'] == 1) | (house_df['other_won'] == 1)]
print(house_called_df.shape)
# Out:
# (419, 13)

# %%
house_called_df.to_csv("clean_csv_11_23/house.csv")

# %% [markdown]
# # Senate data

# %%
with open('senate_11-23.json') as f:
  senate_json = json.load(f)

# %%
random_race = senate_json['data']['races'][0]
print(random_race.keys())
pprint.pprint(random_race['candidates'])
# Out:
# dict_keys(['race_id', 'race_slug', 'url', 'state_page_url', 'ap_polls_page', 'race_type', 'election_type', 'election_date', 'runoff', 'race_name', 'office', 'officeid', 'nyt_race_description', 'race_rating', 'seat', 'seat_name', 'state_id', 'state_slug', 'state_name', 'state_nyt_abbrev', 'state_shape', 'state_aspect_ratio', 'party_id', 'uncontested', 'report', 'result', 'result_source', 'gain', 'lost_seat', 'votes', 'absentee_votes', 'absentee_counties', 'absentee_count_progress', 'absentee_outstanding', 'absentee_max_ballots', 'provisional_outstanding', 'provisional_count_progress', 'poll_display', 'poll_countdown_display', 'poll_waiting_display', 'poll_time', 'poll_time_short', 'precincts_reporting', 'precincts_total', 'reporting_display', 'reporting_value', 'eevp', 'tot_exp_vote', 'eevp_source', 'eevp_value', 'eevp_display', 'county_data_source', 'incumbent_party', 'no_forecast', 'last_updated', 'candidates', 'has_incumbent', 'leader_margin_value', 'leader_margin_votes', 'leader_margin_display', 'leader_margin_name_display', 'leader_party_id', 'counties', 'expectations_text', 'expectations_text_short', 'absentee_ballot_deadline', 'absentee_postmark_deadline', 'update_sentences', 'race_diff', 'winnerCalledTimestamp', 'timeseries'])
# [{'absentee_percent': 43.8,
#   'absentee_votes': 75946,
#   'candidate_id': 'sullivan-64262-2-s',
#   'candidate_key': 'sullivand',
#   'electoral_votes': 0,
#   'first_name': 'Dan',
#   'has_image': False,
#   'img_url': 'https://static01.nyt.com/elections-assets/2020/assets/images/candidates/sullivan-64262-2-s.png',
#   'incumbent': True,
#   'last_name': 'Sullivan',
#   'link': '',
#   'name_display': 'Dan Sullivan',
#   'order': 1,
#   'party_id': 'republican',
#   'percent': 54,
#   'percent_display': '54.0',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 190747,
#   'winner': True},
#  {'absentee_percent': 53,
#   'absentee_votes': 91910,
#   'candidate_id': 'gross-20073397-2-s',
#   'candidate_key': 'grossa',
#   'electoral_votes': 0,
#   'first_name': 'Al',
#   'has_image': False,
#   'img_url': 'https://static01.nyt.com/elections-assets/2020/assets/images/candidates/gross-20073397-2-s.png',
#   'incumbent': False,
#   'last_name': 'Gross',
#   'link': '',
#   'name_display': 'Al Gross',
#   'order': 2,
#   'party_id': 'democrat',
#   'percent': 41.3,
#   'percent_display': '41.3',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 145890,
#   'winner': False},
#  {'absentee_percent': 3.2,
#   'absentee_votes': 5568,
#   'candidate_id': 'howe-20073751-2-s',
#   'candidate_key': 'howej',
#   'electoral_votes': 0,
#   'first_name': 'John Wayne',
#   'has_image': False,
#   'img_url': None,
#   'incumbent': False,
#   'last_name': 'Howe',
#   'link': '',
#   'name_display': 'John Wayne Howe',
#   'order': 6,
#   'party_id': 'alaskan-independence',
#   'percent': 4.7,
#   'percent_display': '4.7',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 16660,
#   'winner': False}]

# %%
results = defaultdict(list)
# keys: state_id, d_votes, r_votes, other_votes, d_vote_share, r_vote_share, d_winner, r_winner, STATEFP, CD114FP

for r in senate_json['data']['races']:
    if r['leader_margin_votes'] is None or len(r['leader_party_id']) == 0:
        # skip if the data is insufficient
        continue
    race_results = {'democrat': 0, 'republican': 0, 'other': 0}
    winning_party = {'d_won': 0, 'r_won': 0, 'other_won': 0}
    for c in r['candidates']:
        if c['party_id'] not in ['democrat', 'republican']:
            c['party_id'] = 'other'
        race_results[c['party_id']] += c['votes']
        if c['winner']:
            if c['party_id'] == 'democrat':
                winning_party['d_won'] = 1
            elif c['party_id'] == 'republican':
                winning_party['r_won'] = 1
            else:
                winning_party['other_won'] = 1
                
    results['state_id'].append(r['state_id'])
    results['STATEFP'].append(state_codes[r['state_id']])
    
    # vote counts
    results['d_votes'].append(race_results['democrat'])
    results['r_votes'].append(race_results['republican'])
    results['other_votes'].append(race_results['other'])
    # vote shares
    total_votes = sum(race_results.values())
    results['d_vote_share'].append(race_results['democrat'] / total_votes)
    results['r_vote_share'].append(race_results['republican'] / total_votes)
    results['other_vote_share'].append(race_results['other'] / total_votes)
    
    for k in winning_party.keys():
        results[k].append(winning_party[k])

# %%
senate_df = pd.DataFrame.from_dict(results)
senate_df.head()
# Out:
#   state_id STATEFP  d_votes  r_votes  other_votes  d_vote_share  r_vote_share  \
# 0       AK      02   145890   190747        16660      0.412939      0.539906
# 1       AL      01   913999  1385344         3869      0.396837      0.601483
# 2       AR      05        0   792891       399064      0.000000      0.665202
# 3       AZ      04  1716467  1637661          594      0.511657      0.488166
# 4       CO      08  1730741  1429111        75003      0.535029      0.441785
#
#    other_vote_share  d_won  r_won  other_won
# 0          0.047156      0      1          0
# 1          0.001680      0      1          0
# 2          0.334798      0      1          0
# 3          0.000177      1      0          0
# 4          0.023186      1      0          0

# %%
print(senate_df.shape)
# some sanity checks
print(senate_df['d_won'].sum())
print(senate_df['r_won'].sum())
print(senate_df['other_won'].sum())
# Out:
# (35, 11)
# 13
# 20
# 0

# %%
senate_called_df = senate_df[(senate_df['d_won'] == 1) | (senate_df['r_won'] == 1) | (senate_df['other_won'] == 1)]
print(senate_called_df.shape)
# Out:
# (33, 11)

# %%
senate_called_df.to_csv("clean_csv_11_23/senate.csv")

# %% [markdown]
# ## Presidential results

# %%
with open('president_11-23.json') as f:
  president_json = json.load(f)

# %%
random_race = president_json['data']['races'][0]
print(random_race.keys())
pprint.pprint(random_race['candidates'])
# Out:
# dict_keys(['race_id', 'race_slug', 'url', 'state_page_url', 'ap_polls_page', 'race_type', 'election_type', 'election_date', 'runoff', 'race_name', 'office', 'officeid', 'race_rating', 'seat', 'seat_name', 'state_id', 'state_slug', 'state_name', 'state_nyt_abbrev', 'state_shape', 'state_aspect_ratio', 'party_id', 'uncontested', 'report', 'result', 'result_source', 'gain', 'lost_seat', 'votes', 'electoral_votes', 'absentee_votes', 'absentee_counties', 'absentee_count_progress', 'absentee_outstanding', 'absentee_max_ballots', 'provisional_outstanding', 'provisional_count_progress', 'poll_display', 'poll_countdown_display', 'poll_waiting_display', 'poll_time', 'poll_time_short', 'precincts_reporting', 'precincts_total', 'reporting_display', 'reporting_value', 'eevp', 'tot_exp_vote', 'eevp_source', 'eevp_value', 'eevp_display', 'county_data_source', 'incumbent_party', 'no_forecast', 'last_updated', 'candidates', 'has_incumbent', 'leader_margin_value', 'leader_margin_votes', 'leader_margin_display', 'leader_margin_name_display', 'leader_party_id', 'counties', 'votes2016', 'margin2016', 'clinton2016', 'trump2016', 'votes2012', 'margin2012', 'expectations_text', 'expectations_text_short', 'absentee_ballot_deadline', 'absentee_postmark_deadline', 'update_sentences', 'race_diff', 'winnerCalledTimestamp', 'timeseries'])
# [{'absentee_percent': 41.8,
#   'absentee_votes': 72953,
#   'candidate_id': 'trump-8639',
#   'candidate_key': 'trumpd',
#   'electoral_votes': 3,
#   'first_name': 'Donald J.',
#   'has_image': True,
#   'img_url': 'https://static01.nyt.com/elections-assets/2020/assets/images/candidates/trumpd.png',
#   'incumbent': True,
#   'last_name': 'Trump',
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/donald-trump.html',
#   'name_display': 'Donald J. Trump',
#   'order': 3,
#   'party_id': 'republican',
#   'percent': 53.1,
#   'percent_display': '53.1',
#   'pronoun': 'he',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 189457,
#   'winner': True},
#  {'absentee_percent': 55.1,
#   'absentee_votes': 96128,
#   'candidate_id': 'biden-1036',
#   'candidate_key': 'bidenj',
#   'electoral_votes': 0,
#   'first_name': 'Joseph R.',
#   'has_image': True,
#   'img_url': 'https://static01.nyt.com/elections-assets/2020/assets/images/candidates/bidenj.png',
#   'incumbent': False,
#   'last_name': 'Biden',
#   'link': 'https://www.nytimes.com/interactive/2020/us/elections/joe-biden.html',
#   'name_display': 'Joseph R. Biden Jr.',
#   'order': 4,
#   'party_id': 'democrat',
#   'percent': 43,
#   'percent_display': '43.0',
#   'pronoun': 'he',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 153551,
#   'winner': False},
#  {'absentee_percent': 2,
#   'absentee_votes': 3573,
#   'candidate_id': 'jorgensen-20062680-2-p',
#   'candidate_key': 'jorgensenj',
#   'electoral_votes': 0,
#   'first_name': 'Jo',
#   'has_image': False,
#   'img_url': 'https://static01.nyt.com/elections-assets/2020/assets/images/candidates/jorgensenj.png',
#   'incumbent': False,
#   'last_name': 'Jorgensen',
#   'link': '',
#   'name_display': 'Jo Jorgensen',
#   'order': 7,
#   'party_id': 'libertarian',
#   'percent': 2.5,
#   'percent_display': '2.5',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 8867,
#   'winner': False},
#  {'absentee_percent': 0.6,
#   'absentee_votes': 1018,
#   'candidate_id': 'ventura-20067453-2-p',
#   'candidate_key': 'venturaj',
#   'electoral_votes': 0,
#   'first_name': 'Jesse',
#   'has_image': False,
#   'img_url': None,
#   'incumbent': False,
#   'last_name': 'Ventura',
#   'link': '',
#   'name_display': 'Jesse Ventura',
#   'order': 10,
#   'party_id': 'green',
#   'percent': 0.7,
#   'percent_display': '0.7',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 2663,
#   'winner': False},
#  {'absentee_percent': 0.2,
#   'absentee_votes': 402,
#   'candidate_id': 'blankenship-19247-2-p',
#   'candidate_key': 'blankenshipd',
#   'electoral_votes': 0,
#   'first_name': 'Don',
#   'has_image': False,
#   'img_url': 'https://static01.nyt.com/elections-assets/2020/assets/images/candidates/blankenshipd.png',
#   'incumbent': False,
#   'last_name': 'Blankenship',
#   'link': '',
#   'name_display': 'Don Blankenship',
#   'order': 6,
#   'party_id': 'constitution',
#   'percent': 0.3,
#   'percent_display': '0.3',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 1120,
#   'winner': False},
#  {'absentee_percent': 0.2,
#   'absentee_votes': 275,
#   'candidate_id': 'pierce-20073903-2-p',
#   'candidate_key': 'pierceb',
#   'electoral_votes': 0,
#   'first_name': 'Brock',
#   'has_image': False,
#   'img_url': None,
#   'incumbent': False,
#   'last_name': 'Pierce',
#   'link': '',
#   'name_display': 'Brock Pierce',
#   'order': 8,
#   'party_id': 'independent',
#   'percent': 0.2,
#   'percent_display': '0.2',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 821,
#   'winner': False},
#  {'absentee_percent': 0.1,
#   'absentee_votes': 107,
#   'candidate_id': 'de-la-fuente-64542-2-p',
#   'candidate_key': 'de_la_fuenter',
#   'electoral_votes': 0,
#   'first_name': 'Roque',
#   'has_image': False,
#   'img_url': None,
#   'incumbent': False,
#   'last_name': 'De La Fuente',
#   'link': '',
#   'name_display': 'Roque De La Fuente',
#   'order': 10,
#   'party_id': 'Ali',
#   'percent': 0.1,
#   'percent_display': '0.1',
#   'result_source': 'NYT',
#   'runoff': False,
#   'votes': 317,
#   'winner': False}]

# %%
results = defaultdict(list)
# keys: state_id, d_votes, r_votes, other_votes, d_vote_share, r_vote_share, d_winner, r_winner, STATEFP, CD114FP

for r in president_json['data']['races']:
    if r['leader_margin_votes'] is None or len(r['leader_party_id']) == 0:
        # skip if the data is insufficient
        continue
    race_results = {'democrat': 0, 'republican': 0, 'other': 0}
    winning_party = {'d_won': 0, 'r_won': 0, 'other_won': 0}
    for c in r['candidates']:
        if c['party_id'] not in ['democrat', 'republican']:
            c['party_id'] = 'other'
        race_results[c['party_id']] += c['votes']
        if c['winner']:
            if c['party_id'] == 'democrat':
                winning_party['d_won'] = 1
            elif c['party_id'] == 'republican':
                winning_party['r_won'] = 1
            else:
                winning_party['other_won'] = 1
                
    results['state_id'].append(r['state_id'])
    results['STATEFP'].append(state_codes[r['state_id']])
    
    # vote counts
    results['d_votes'].append(race_results['democrat'])
    results['r_votes'].append(race_results['republican'])
    results['other_votes'].append(race_results['other'])
    # vote shares
    total_votes = sum(race_results.values())
    results['d_vote_share'].append(race_results['democrat'] / total_votes)
    results['r_vote_share'].append(race_results['republican'] / total_votes)
    results['other_vote_share'].append(race_results['other'] / total_votes)
    
    for k in winning_party.keys():
        results[k].append(winning_party[k])

# %%
prez_df = pd.DataFrame.from_dict(results)
prez_df.head()
# Out:
#   state_id STATEFP   d_votes  r_votes  other_votes  d_vote_share  \
# 0       AK      02    153551   189457        13788      0.430361
# 1       AL      01    849624  1441170        32488      0.365700
# 2       AR      05    423602   759736        34403      0.347859
# 3       AZ      04   1672143  1661686        52016      0.493863
# 4       CA      06  11020102  5934931       374981      0.635897
#
#    r_vote_share  other_vote_share  d_won  r_won  other_won
# 0      0.530995          0.038644      0      1          0
# 1      0.620316          0.013984      0      1          0
# 2      0.623890          0.028251      0      1          0
# 3      0.490774          0.015363      1      0          0
# 4      0.342465          0.021638      1      0          0

# %%
print(prez_df.shape)
# some sanity checks
print(prez_df['d_won'].sum()) # :')
print(prez_df['r_won'].sum())
print(prez_df['other_won'].sum())
# Out:
# (51, 11)
# 26
# 25
# 0

# %%
prez_called_df = prez_df[(prez_df['d_won'] == 1) | (prez_df['r_won'] == 1) | (prez_df['other_won'] == 1)]
print(prez_called_df.shape)
# Out:
# (51, 11)

# %%
prez_called_df.to_csv("clean_csv_11_23/president.csv")
